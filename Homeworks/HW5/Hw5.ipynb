# %% [markdown]
# # Лабораторна робота 5
#
# ## Завдання 1
#
# Розгляньте групу матриць за множенням
#
# $$G = \left\langle \left(\begin{array}{rrr}
# 1 & 0 & 1 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{array}\right),  \left(\begin{array}{rrr}
# 1 & 0 & 0 \\
# 0 & 1 & 1 \\
# 0 & 0 & 1
# \end{array}\right)\right\rangle$$
#
# Дайте відповідь на наступні питання:
#
# 1. _Чи є група G скінченною?_
# 2. _Чи є група G комутативною?_
# 3. _Який вигляд мають елементи групи G?_
# 4. _Які порядки мають елементи групи G?_
# 5. _Чому ізоморфна група G?_
#
#
# __Відповіді__:
# 1. ні
# 2. так
# 3. $$\begin{pmatrix}
# 1 & 0 & n \\
# 0 & 1 & m \\
# 0 & 0 & 1
# \end{pmatrix}$$
#
#
# 4. у нейтрального 1, у всих інших $\infty$
# 5. Дивлячись на третій пункт, доволі легко побудувати ізоморфізм,  m -> $\mathbb{Z}$, n -> $\mathbb{Z}$; таким чином   $\mathbb{G} \cong \mathbb{Z} \times \mathbb{Z}$ -> $\mathbb{G} \cong \mathbb{Z}^2$

# %%
from sage.all import matrix
var('n')
var('m')
a = matrix([[1,0,1], [0,1,0], [0,0,1]])
b = matrix([[1, 0, 0], [0,1,1],[0,0,1]])
G = MatrixGroup([a, b])

print(G.is_finite())
print(G.is_abelian())
# print(a*b)
# print("++++++++++++++")
# print(b*a)
# print("++++++++++++++")
# square
# print(b**2)
# print("++++++++++++++")
# print(a**2)
# print("++++++++++++++")
# print(b**n)
# print("++++++++++++++")
# print(a**m)
# print("++++++++++++++")
# print(b**-n)
# print("++++++++++++++")
# print(a**-m)
# print("++++++++++++++")

print(b**n * a**m)
print("++++++++++++++")
print( a**m * b**n)
# Out:
# False
# True
# [1 0 m]
# [0 1 n]
# [0 0 1]
# ++++++++++++++
# [1 0 m]
# [0 1 n]
# [0 0 1]

# %% [markdown]
# ## Завдання 2
#
# Розгляньте групу матриць за множенням:
#
# $$G = \left\langle \left(\begin{array}{rr}
# 1 & -1 \\
# -1 & 2
# \end{array}\right), \left(\begin{array}{rr}
# 3 & 2 \\
# 2 & 1
# \end{array}\right) \right\rangle$$
#
# Дайте відповідь на наступні питання:
#
# 1. _Чи є група G скінченною?_
# 2. _Чи є група G комутативною?_
# 3. _Який вигляд мають елементи групи G?_
# 4. _Які порядки мають елементи групи G?_
# 5. _Чому ізоморфна група G?_
#
#
# __Відповіді__:
# 1. ні
# 2. так
# 3.
# $$\begin{pmatrix}
# n & n-m \\
# n-m & m
# \end{pmatrix}$$
# 5. у нейтрального 1, у всих інших $\infty$
# 6. Доволі легко побудувати ізоморфізм, такий же як і в попередньому пункті тобто n -> $\mathbb{Z}$, m -> $\mathbb{Z}$; таким чином   $\mathbb{G} \cong \mathbb{Z} \times \mathbb{Z}$ -> $\mathbb{G} \cong \mathbb{Z}^2$

# %%
var('n')
var('m')


a = matrix([[1, -1], [-1, 2]])
b = matrix([[3, 2], [2, 1]])

G = MatrixGroup([a, b])

print(G.is_finite())
print(G.is_abelian())

# print(a**2)
# print("++++++++++++++")
# print(b**2)
# print("++++++++++++++")
print(a*b)
print("++++++++++++++")
print(b*a)
print("++++++++++++++")
print(a**2 * b**3)
# print(a**n)
# print("++++++++++++++")
# print(b**m)
# print("++++++++++++++")

x = (a**n * b**m)
y = (b**m * a**n)

if x == y:
    print("yes")
else:
    print("no")
# print(x)
# print(y)
# for i in range(10):
#     print(a**i)
# print("++++++++++++++")
# for j in range(10):
#     print(b**j)
# k = 0
# while(k > -10):
#     print(k)
#     print(a**k)
#     k -= 1
print(a^2)
print(a^-2)
# Out:
# False
# True
# [1 1]
# [1 0]
# ++++++++++++++
# [1 1]
# [1 0]
# ++++++++++++++
# [8 5]
# [5 3]
# yes
# [ 2 -3]
# [-3  5]
# [5 3]
# [3 2]

# %% [markdown]
# ## Завдання 3
#
# Розгляньте групу матриць за множенням:
#
# $$K = \left\langle \left(\begin{array}{rrr}
# -1 & 0 & 0 \\
# 0 & 1 & \frac{1}{2} \\
# 0 & 0 & 1
# \end{array}\right),
# \left(\begin{array}{rrr}
# 1 & 0 & 1 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{array}\right) \right\rangle$$
#
# Дайте відповідь на наступні питання:
#
# 1. _Чи є група K скінченною?_
# 2. _Чи є група K комутативною?_
# 3. _Який вигляд мають елементи групи K?_
# 4. _Які порядки мають елементи групи K?_
#
# __Відповіді__:
# 1. ні
# 2. ні
# 3. $$\begin{pmatrix}
# (-1)^{\sum_{i=0}^{p} n_i
# } & 0 & D_{i} \\
# 0 & 0 & \frac{\sum_{i=0}^{p} n_i}{ 2} \\
# 0 & 0 & 1
# \end{pmatrix}$$
# де $D_{i} =  \sum_{i=0}^{p} (-1)^{C_{i}} m_{i}$ де $C_{i} = \sum_{k = 0}^i n_{i}$
# варто зауважити що $a = K_{1}$, $b = K_{2}$ кожну дію на множині ми моженмо розглянути як певний $\prod_{i = 0}^{t} a^{n_i} b^{m_i}$, якшо добуток починається з $b^{l}$, то ми просто дописуємо на початок $a^0$, аналогічно з $b^0$ в кінці також зауважу що $\prod_{i = x}^{y} a^{n_i}$ = $a^{\sum_{i = x}^{y}n_i}$ те ж саме і з b. Тобто якщо брати прям загальний загальний член то матимемо $$\begin{pmatrix}
# (-1)^l & 0 & m \\
# 0 & 0 & \frac{n}{ 2} \\
# 0 & 0 & 1
# \end{pmatrix}$$
# l, m, n $\in$ $\mathbb{Z}$, але як ми побачили раніше l, m, n залежать від $m_{i}$ та $n_{i}$ (просто нагадування)
#
# 5. $M_{1}$ (одинична) порядку один, всі інші $\infty$
#
#
#
# __Додаткова задача:__
# Опишіть підгрупи групи K з точністю до ізоморфізму.
# Як видно з a^n $$\begin{pmatrix}
# (-1)^n & 0 & 0 \\
# 0 & 1 & \frac{n}{2} \\
# 0 & 0 & 1
# \end{pmatrix}$$
# підгрупа породжена суто піднесенням а в степінь $\cong \mathbb{Z}$ теж саме можна сказати і про b^n (тут навіть більш очевидно) $$\begin{pmatrix}
# 1 & 0 & m \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{pmatrix}$$
# щодо інших підгруп породжених $\prod_{i = 0}^{t} b^{m_i} a^{n_i}$ або $\prod_{i = 0}^{t} a^{n_i} b^{m_i}$ ми отримаємо результат наведений вище в номері 3. а він в свою чергу $\cong \mathbb{Z}^2$, як і повна тривіальна підгрупа. Ну і залишилась друга тривіальна підгрупа з одиничної матриці $E_{3}$

# %%
var('n')
var('m')
var('k')

a = matrix([[-1, 0, 0],[0, 1, 1/2],[0, 0, 1]])
b = matrix([[1, 0, 1],[0, 1, 0],[0, 0, 1]])
e = matrix([[1, 0, 0], [0, 1, 0], [0, 0, 1]])
G = MatrixGroup([a, b])

print(G.is_finite())
print(G.is_abelian())
# print(a*b)
# print("++++++++++++++++++")
# print(b*a)

# print("++++++++++++++++++")
print(a**n)
print("++++++++++++++++++")
print(b**m)

x = (a**n * b**m)
y = (b**m * a**n)

print(x)
print("=============")
print(y)
print("=============")

print(x*a**k)
print("=============")
print(y*a**k)
print("=============")
print(x*b**k)
print("=============")
print(y*b**k)

# if x == y:
#     print("yes")
# else:
#     print("no")


a**2 * b**3 *a**1 * b^3
# Out:
# False
# False
# [(-1)^n      0      0]
# [     0      1  1/2*n]
# [     0      0      1]
# ++++++++++++++++++
# [1 0 m]
# [0 1 0]
# [0 0 1]
# [  (-1)^n        0 (-1)^n*m]
# [       0        1    1/2*n]
# [       0        0        1]
# ...
# [(-1)^n      0      m]
# [     0      1  1/2*n]
# [     0      0      1]
# ...
# [(-1)^k*(-1)^n             0      (-1)^n*m]
# [            0             1 1/2*k + 1/2*n]
# [            0             0             1]
# ...
# [(-1)^k*(-1)^n             0             m]
# [            0             1 1/2*k + 1/2*n]
# [            0             0             1]
# ...
# [             (-1)^n                   0 (-1)^n*k + (-1)^n*m]
# [                  0                   1               1/2*n]
# [                  0                   0                   1]
# ...
# [      (-1)^n            0 (-1)^n*k + m]
# [           0            1        1/2*n]
# [           0            0            1]
# [ -1   0   0]
# [  0   1 3/2]
# [  0   0   1]
